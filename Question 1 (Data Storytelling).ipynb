# %%
# Uncovering Stories from Singapore’s HDB Resale Market

# %%
# Over the past decade, Singapore’s HDB resale market has undergone notable changes — from cooling measures and COVID-19 disruptions to the emergence of million-dollar flats. But while much attention is paid to price trends and housing supply, the story of the agent is often overlooked.

# Using open datasets from CEA (agent transactions) and HDB (resale flat prices), we explored:

# Where agents are most active

# What types of flats they focus on

# How activity and pricing evolved through the pandemic

# Let’s explore what the data reveals.

# %%
import requests
import time
import pandas as pd
from io import StringIO
import plotly.graph_objects as go
import warnings
warnings.filterwarnings(action="ignore")


CEA_DATASET_ID = "d_ee7e46d3c57f7865790704632b0aef71"
RESALE_DATASET_ID='d_8b84c4ee58e3cfc0ece0d773c8ca6abc'
max_tries=3

def load_dataset_as_dataframe(DATASET_ID):
    INITIATE_URL = f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/initiate-download"
    POLL_URL = f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/poll-download"
    init_resp = requests.get(INITIATE_URL)
    init_resp.raise_for_status()

    for _ in range(max_tries):
        time.sleep(2)
        poll_resp = requests.get(POLL_URL)
        poll_resp.raise_for_status()
        download_url = poll_resp.json().get("data", {}).get("url")
        if download_url:
            break
    else:
        raise TimeoutError("Timed out waiting for dataset download URL.")

    csv_resp = requests.get(download_url)
    csv_resp.raise_for_status()
    df = pd.read_csv(StringIO(csv_resp.text))
    return df

cea_df = load_dataset_as_dataframe(CEA_DATASET_ID)
resale_df = load_dataset_as_dataframe(RESALE_DATASET_ID)

# %%
cea_df['transaction_type'].value_counts()
# Out:
# transaction_type
# WHOLE RENTAL    560785
# RESALE          452690
# ROOM RENTAL     114684
# NEW SALE         53781
# SUB-SALE           176
# Name: count, dtype: int64

# %%
cea_df = cea_df[cea_df['transaction_type'] == 'RESALE']

# %%
cea_df['month'] = pd.to_datetime(cea_df['transaction_date'], format='%b-%Y')
# Out:
# /tmp/ipython-input-37-3964039917.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cea_df
# Out:
#         salesperson_name transaction_date salesperson_reg_num  \
# 0            SOH HUI HUA       2017-10-01            P000003I
# 1            SOH HUI HUA       2018-03-01            P000003I
# 2            SOH HUI HUA       2017-01-01            P000003I
# 3            SOH HUI HUA       2018-05-01            P000003I
# 4            SOH HUI HUA       2017-11-01            P000003I
# ...                  ...              ...                 ...
# 1182105                -       2023-12-01                   -
# 1182106                -       2023-12-01                   -
# 1182107                -       2023-12-01                   -
# 1182108                -       2023-12-01                   -
# 1182115                -       2020-02-01                   -
#
#                   property_type transaction_type represented             town  \
# 0                           HDB           RESALE      SELLER           YISHUN
# 1                           HDB           RESALE       BUYER  KALLANG/WHAMPOA
# 2                           HDB           RESALE       BUYER           YISHUN
# 3                           HDB           RESALE      SELLER    CHOA CHU KANG
# 4                           HDB           RESALE      SELLER    CHOA CHU KANG
# ...                         ...              ...         ...              ...
# 1182105                     HDB           RESALE       BUYER      BUKIT MERAH
# 1182106                     HDB           RESALE      SELLER        WOODLANDS
# 1182107                     HDB           RESALE       BUYER          HOUGANG
# 1182108                     HDB           RESALE       BUYER           YISHUN
# 1182115  CONDOMINIUM_APARTMENTS           RESALE      SELLER                -
#
#         district general_location  year      month
# 0              -                -  2017 2017-10-01
# 1              -                -  2018 2018-03-01
# 2              -                -  2017 2017-01-01
# 3              -                -  2018 2018-05-01
# 4              -                -  2017 2017-11-01
# ...          ...              ...   ...        ...
# 1182105        -                -  2023 2023-12-01
# 1182106        -                -  2023 2023-12-01
# 1182107        -                -  2023 2023-12-01
# 1182108        -                -  2023 2023-12-01
# 1182115       14   Geylang/ Eunos  2020 2020-02-01
#
# [452690 rows x 11 columns]

# %%
cea_df.describe()
# Out:
#                     transaction_date           year  \
# count                         452690  452690.000000
# mean   2021-11-27 05:51:17.904968192    2021.451660
# min              2017-01-01 00:00:00    2017.000000
# 25%              2020-05-01 00:00:00    2020.000000
# 50%              2022-02-01 00:00:00    2022.000000
# 75%              2023-11-01 00:00:00    2023.000000
# max              2025-07-01 00:00:00    2025.000000
# std                              NaN       2.308618
#
#                                month
# count                         452690
# mean   2021-11-27 05:51:17.904968192
# min              2017-01-01 00:00:00
# 25%              2020-05-01 00:00:00
# 50%              2022-02-01 00:00:00
# 75%              2023-11-01 00:00:00
# max              2025-07-01 00:00:00
# std                              NaN

# %%
resale_df
# Out:
#             month        town         flat_type block        street_name  \
# 0      2017-01-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...           ...         ...               ...   ...                ...
# 211753 2025-04-01      YISHUN         EXECUTIVE   828       YISHUN ST 81
# 211754 2025-05-01      YISHUN         EXECUTIVE   828       YISHUN ST 81
# 211755 2025-07-01      YISHUN         EXECUTIVE   824       YISHUN ST 81
# 211756 2025-05-01      YISHUN  MULTI-GENERATION   632       YISHUN ST 61
# 211757 2025-07-01      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            44.0          Improved                 1979
# 1          01 TO 03            67.0    New Generation                 1978
# 2          01 TO 03            67.0    New Generation                 1980
# 3          04 TO 06            68.0    New Generation                 1980
# 4          01 TO 03            67.0    New Generation                 1980
# ...             ...             ...               ...                  ...
# 211753     04 TO 06           146.0        Maisonette                 1988
# 211754     04 TO 06           142.0         Apartment                 1988
# 211755     04 TO 06           146.0        Maisonette                 1987
# 211756     04 TO 06           147.0  Multi Generation                 1987
# 211757     01 TO 03           171.0  Multi Generation                 1987
#
#            remaining_lease  resale_price  year
# 0       61 years 04 months      232000.0  2017
# 1       60 years 07 months      250000.0  2017
# 2       62 years 05 months      262000.0  2017
# 3        62 years 01 month      265000.0  2017
# 4       62 years 05 months      265000.0  2017
# ...                    ...           ...   ...
# 211753  61 years 09 months      975000.0  2025
# 211754  61 years 09 months     1000000.0  2025
# 211755  61 years 05 months      980000.0  2025
# 211756  61 years 06 months      945000.0  2025
# 211757  61 years 06 months     1095000.0  2025
#
# [211758 rows x 12 columns]

# %%
cea_df['transaction_date'] = pd.to_datetime(cea_df['transaction_date'], format="%b-%Y")
cea_df['year'] = cea_df['transaction_date'].dt.year
# Out:
# /tmp/ipython-input-42-1602021383.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-42-1602021383.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# The Resilient Agent: Post-COVID Recovery
# Even as lockdowns froze much of the economy in 2020, resale activity recovered strongly in 2021 and beyond.
# Agent transactions — which dipped due to viewing restrictions and uncertainty — surged back as buyers returned and prices began to climb.

# %%
cea_resale = cea_df[cea_df['transaction_type'] == 'RESALE']

agent_counts = cea_resale.groupby('year').size().reset_index(name='agent_transactions')

resale_avg = resale_df.groupby('year')['resale_price'].mean().reset_index(name='avg_resale_price')

merged = pd.merge(agent_counts, resale_avg, on='year')

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar(x=merged['year'], y=merged['agent_transactions'], name="Agent Transactions", marker_color='skyblue'))
fig.add_trace(go.Scatter(x=merged['year'], y=merged['avg_resale_price'], name="Avg Resale Price", mode='lines+markers', yaxis='y2'))
fig.update_layout(
    title=" Agent Recovery in the Resale Market (Post-COVID)",
    xaxis_title="Year",
    yaxis=dict(title="Agent Transactions"),
    yaxis2=dict(title="Average Resale Price (SGD)", overlaying='y', side='right'),
    template="plotly_white", height=500
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b277fc56-20bc-4dfb-ac49-e5c04465adf9" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b277fc56-20bc-4dfb-ac49-e5c04465adf9")) {                    Plotly.newPlot(                        "b277fc56-20bc-4dfb-ac49-e5c04465adf9",                        [{"marker":{"color":"skyblue"},"name":"Agent Transactions","x":[2017,2018,2019,2020,2021,2022,2023,2024,2025],"y":[31162,35674,30468,47320,74181,63964,64161,70938,34822],"type":"bar"},{"mode":"lines+markers","name":"Avg Resale Price","x":[2017,2018,2019,2020,2021,2022,2023,2024,2025],"y":[443888.5205714564,441282.06370344607,432137.9129018299,452279.38497064245,511381.2390012721,549714.3307151946,571806.0079770132,612599.9011712715,648957.9529766497],"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parco ...

# %%
#  Hidden Battlegrounds: Agent Activity vs Affordability
# While towns like Bishan and Queenstown dominate headlines with million-dollar flats, we found surprising hotspots of agent activity in more affordable towns
# like Yishun and Woodlands & Sengkang.

# These areas show:

# High agent transaction volume
# Moderate resale prices
# High flat turnover

# %%
# Agent activity by town
town_agents = cea_resale.groupby('town').size().reset_index(name='agent_deals')

# Average resale price by town
town_prices = resale_df.groupby('town')['resale_price'].mean().reset_index(name='avg_price')

# Volume by town
town_volume = resale_df.groupby('town').size().reset_index(name='flats_sold')

# Merge
merged_town = town_agents.merge(town_prices, on='town').merge(town_volume, on='town')

# Plot
import plotly.express as px
fig = px.scatter(
    merged_town, x='avg_price', y='agent_deals', size='flats_sold', color='town',
    title="Agent Activity vs Affordability",
    labels={'avg_price': 'Avg Resale Price (SGD)', 'agent_deals': 'Agent Transactions'},
    size_max=60
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b2e0215e-87c5-48bc-91b4-71bf997ea828" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2e0215e-87c5-48bc-91b4-71bf997ea828")) {                    Plotly.newPlot(                        "b2e0215e-87c5-48bc-91b4-71bf997ea828",                        [{"hovertemplate":"town=ANG MO KIO\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ANG MO KIO","marker":{"color":"#636efa","size":[8664],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"ANG MO KIO","orientation":"v","showlegend":true,"x":[472101.1486334257],"xaxis":"x","y":[13057],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BEDOK\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BEDOK","marker":{"color":"#EF553B","size":[11051],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BEDOK","orientation":"v","showlegend":true,"x":[474074.31508460775],"xaxis":"x","y":[17296],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BISHAN\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BISHAN","marker":{"color":"#00cc96","size":[3724],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BISHAN","orientation":"v","showlegend":true,"x":[700589.6425241677],"xaxis":"x","y":[5241],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BUKIT BATOK\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BUKIT BATOK","marker":{"color":"#ab63fa","size":[8694],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BUKIT BATOK","orientation":"v","showlegend":true,"x":[492895.8933183805],"xaxis":"x","y":[13930],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BUKIT MERAH\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BUKIT MERAH","marker":{"color":"#FFA15A","size":[8103],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BUKIT MERAH","orientation":"v","showlegend":true,"x":[630153.4399160806],"xaxis":"x","y":[11268],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BUKIT PANJANG\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BUKIT PANJANG","marker":{"color":"#19d3f3","size":[7621],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BUKIT PANJANG","orientation":"v","showlegend":true,"x":[495020.1883847264],"xaxis":"x","y":[11919],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=BUKIT TIMAH\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions=%{y}\u003cbr\u003eflats_sold=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BUKIT TIMAH","marker":{"color":"#FF6692","size":[516],"sizemode":"area","sizeref":4.828888888888889,"symbol":"circle"},"mode":"markers","name":"BUKIT TIMAH","orientation":"v","showlegend":true,"x":[766590.426124031],"xaxis":"x","y":[701],"yaxis":"y","type":"scatter"},{"hovertemplate":"town=CENTRAL AREA\u003cbr\u003eAvg Resale Price (SGD)=%{x}\u003cbr\u003eAgent Transactions= ...

# %%
# The Flat Type Focus: What’s Keeping Agents Busy?
# Agents tend to specialize based on demand patterns. The 4-room flat emerges as the clear leader in transaction volume — striking a balance between size and affordability for families.

# Meanwhile, 5-room and Executive flats, while pricier, attract fewer deals — likely due to a smaller buyer pool or lower availability.

# %%
flat_group = resale_df.groupby('flat_type').size().reset_index(name='resale_transactions')
flat_price = resale_df.groupby('flat_type')['resale_price'].mean().reset_index(name='avg_price')
flat_merged = pd.merge(flat_group, flat_price, on='flat_type')

import plotly.express as px
fig = px.bar(flat_merged.sort_values(by='resale_transactions', ascending=False),
    x='flat_type', y='resale_transactions', color='avg_price',
    title="Flat Types with Most Resale Transactions",
    labels={'resale_transactions': 'Resale Transactions', 'avg_price': 'Avg Resale Price'},
    color_continuous_scale='Blues'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="20947c61-4a9d-46f8-9ea4-f0b3c9fa66e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20947c61-4a9d-46f8-9ea4-f0b3c9fa66e6")) {                    Plotly.newPlot(                        "20947c61-4a9d-46f8-9ea4-f0b3c9fa66e6",                        [{"alignmentgroup":"True","hovertemplate":"flat_type=%{x}\u003cbr\u003eResale Transactions=%{y}\u003cbr\u003eAvg Resale Price=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[521112.3508217526,616007.8555356355,366926.67671324784,723261.8735350443,294677.1734449761,856736.0476190476,209360.97435897434],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["4 ROOM","5 ROOM","3 ROOM","EXECUTIVE","2 ROOM","MULTI-GENERATION","1 ROOM"],"xaxis":"x","y":[89589,52097,50378,15352,4180,84,78],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar" ...
